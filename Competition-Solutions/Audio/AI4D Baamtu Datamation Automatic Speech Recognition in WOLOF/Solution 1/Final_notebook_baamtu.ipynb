# %% [markdown]
# ## GPU Configurations used

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue May 25 13:35:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Loading the necessary libraries and datasets
#
# Here we have saved the entire data in a zipped folder - "AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF.zip"
# <br>
# This zipped folder contains-
# * Train and test csv
# * Audio clips related to the both train and test data that needs to be unzipped
#
# <br>
# We will also create a folder "model_asr" where model checkpoints will be saved.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !mkdir datasets
# !unzip '/content/drive/MyDrive/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF.zip' -d datasets
# !unzip '/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips.zip' -d '/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF'

# !mkdir model_asr

# !pip install --upgrade torch
# !pip install --upgrade datasets
# !pip install --upgrade transformers
# !pip install --upgrade torchaudio
# !pip install --upgrade librosa
# !pip install --upgrade jiwer
# !pip install --upgrade audiomentations
# !pip install --upgrade fuzzywuzzy
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/501ec5ade65f06ac7eeaa5e1843d054aaf2e2d010a422b50387c9bf5367cbc7b03131f392b3a4c129966470d58ab01a21c48b6c54d95c351835ee746e4697f5b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/bc4f81694d79fc1dacd665a8cc95e82899f32c21ff57ddcce0049b1779fb523654f125555ed16b09a2712112039133803b6bfb89e47489d15ffaafbda4315465.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/890343656db76dc7134d640ef92fe53b2065c024d5f8f365044d120a72679158fc4a253a13ccc81a9f4df1c2685b169a7bc9416d5d3cbd08a53b025fd458e08b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/373f142b40729362862b20fb360a05d6362c0ad4917a8059e36a4b8002b45a43fb5ccfac6582ef4984eb5a84e55728f01d16e1748776d39bc18dac4bf86dcb2c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4a1e548e01076b571fd462e13b83ae4a2fed4cfdc7f700f33d1fb0d5b158c1fbac967bd0b193a0f82807d2ece27a6322fac732ecba33251479a7eb9ebe05766c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7a4364236ad3037c0bbe7aaabc5ab6dfdfc14f5b01a5338692a357590b8efc463243cc3fcbeb0b36130909dd0d98966d0a9964795ba5274c2ce7c533b4c031e4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a2e5e7b12f686a292b156dae5e45b04ed89f3770a13f0ff9862d3fcde63291584c872589a6a31b39043f7a5a45eb5f7e1a0ac484f73dab3333f6dbc535807eeb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/bc2969eef33904b9af0045061d50f9948e68c4ac4c3cec91ce394d7a1768afc95edba26f21af9fcbdd4d03ae9a77105a43223db5e42f628b16608a6dc8076f73.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/bc4b51d2f9b5bb6eeff3e4c6d28790d45c1a8413300c159a26199b28a280b8b907ee4b6e2bdbee551cf764f051dbd4e06f340ae76eed46d683042a5652ab3f58.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1e588f4ca97a45ca293e958d3ae370e7dc6d26827442b1de035618174a738489296a8c9acc50a7975e63f638a0cbf601eee77b9130f91cc3c3857f6555135a9d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/484ed8e2cee54686fa1fe8e46c5981feb65643d1d912c5def585b9febe72a61f11a3c6791df2ce8d213de58405afc61a297374bdf480858fd334f3ccbf1c166e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5cfccd3eba5b1527b46eadae5c5e04b93e827de82fa48215ea42c0ef77b62e565bc66364fd1298b3f77087b6d685d7d8ec98a321d7d0de47c684f3de75557a34.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b93ad1df7b12c792d29d1f45e492052da8f5e2ea000e67e4bf754abd7dcc7cc76f9138802a3da5d0319545eb36ee3eda79797cf26903a6b35852afb9815d54d3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9a5baf44093c774d6b5b39674447df1d8a910ba696f18675c6586b8cdaac0e6ec8b94a0df0cbaf82c3baec3dfc7ac87c409060c4bdee8707167ee939d64f46a7.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9d876a71e8ee55443fb0aea44b9d86d98d3219b5007770c5003d88fdfb0aecca7b6cc257f78bb0fd25437f2c384f04f7420cc2c029b624c057147334f4c1e1f0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f0c3cd498d2ce701a8c123f34f83236ec1580fc3735bac3c009a7117a22e9c1471324de0678ef0c22b23b8fa5efdc0940040bb10f81e6e0c4562aa0de8371172.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/126fe76aed8d9fee85c575686c2dc1127ce3b0dc8c7a4a78217488d31edbab59b13e1307ba71e94781cff0e610d764d1fe931b77764b394ad81f93ead96ae38e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d251b5311ba8c37c28731be099bdb7d1ecdbb4a478897441c1dd5f3f0c40e63eb25d13cf06e704356df48906b043c234b2677acee44e99bebcfa782245ce375a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/331ef13ab1ed10552503e66e2c101f2544052ebb77bbca372d58e4cbf4bc76e2ecd742e7a1d01652c8a3f24b1fb5aefdbf47307432b35588f053cf70eb60dc86.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b7008fadececada6ac73c05710ea7f2675d3aef9d6bfe77d82fa1ce4958aca8c4347dee58a361c4b8eb594f917d768485017fc29f03981ccb53d835a5f631606.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/be7c66257f143d3beb122f38523fd7e17e9e9d5ab7e7e58f9e65786774eb8082415d1908ad1607e2386f32d2ee2c6856a1277bd173f76ea898e2635562eb0fb2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0114781b2aea68a04abdfe84d62018126a24b6e01074be4bdb1acbdef7aed284213162f6c4ff835bca8a1539e7980b08bb5928f0f78fdcae584637f81bff1e4d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fd6642b4c40551943c9d5b951a5cbe24294d6bcee5b92ccab274cfde881c2ea185aca130c7b2d13e54b57dbe15b152b6a17f7608121a0a2bf68e485854f04a62.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b035cf0d62f402fb7e47cd21556f41283dbeedbb4f02a8ab30eba3c908e2150b2bb76c911665713cf0c26daaead823e6e47291bfba1f0a8668b8aa19ff4c360e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/40fdcce5d48f3295b6d33ebed9a70ed6369a2dad6331d18d8d062dbe13be1af6f07c9701e49cd4c11e977c6b664b4b54476564eba00dafa4df3ea2210bacc0db.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e827200c7b953ec50f755be8c6e418fe30ea921d364db06d4f9056d60b87a1256f57914a90a257f436315305c03d541a1a96d2687042629679d4bad0ac88826a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d5e4e406dfabdc83ea6ae397e6748f96a45d74d4fb6160e113b1c9062564d2d8d663ea54bd664f289b1236b49fe4c309382ba7b34d2d81bc802adae3ade7bfc1.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2a3ee33565adec42e2d0b2c860d32c22bae3d75e1b233b926f599cc1229387974674ed0b4ac934aac8f6e50afcc2069482dea6b52ba7d55cbe95135032653154.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/85184e8f54931d22936b38f97d123ed7d445aaa62295eff2c54b466529ff4097b1d9443089309ee4dffbb229142040583008032646cdaed9b775902b0d6fda3c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/876651ec078e9c4995ff493736e54e20c5dcf1af698e25c135b38b36938cf2794bbef53a5e1c609330cb0e8d8cb4128086d74d7dcc3e5e0905e2f0e3d954532f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f9f9a4f10aaaf73229cbeaf5898d904a8af6e162b003abc78280a381c484cbff435ef13be16d0fcb03ac0c035a271d3acd826e5c641ac046fad4829f75639ef6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/99763d155c3e7b99fb65769b996fab80adef145dd934742001219f0c9e5fe57bbb586d6faae713340fdaac8b445d50970b22d47bb31a99bee544f164cac21e01.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/59b67a812bbaf201232573d7a05f3c4326ce7262a9d533da4993158cd4f3d0f76027a1e5fe257b58e3d11749d1500c53684521ee806fd828440d630c5a3bc618.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d275404471d524aa2e293e43e9cc9472ec897cf245b915f912f02ea9db736cb06d1b537632a905baa604d648695ba98b80003a5f291510b8c9c43bb6b9910a2c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b8644dd275809d543c32e3423ba4988bf791da722df23172e7fd5310baf22b7f0dc098269f31ab9a067dd4bedbb51a447d7fecb66cc740d0920b371db5acc6d5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8cad174df87fc53d4527778395472c0bdaaed0360d419ea9d5f46c522aa37a3561e86eb39be5267736d525c3c6f1d72cd8a501cb396be62c32c17f2bfd80d42e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/45995614bb259cc63a89cde8133a972f50bf71a06f12162262dc96029a2329497ec637862b8be7f12fce3ea528e96b3c519ce99b8281e39ca3301f2d69c7f8c3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a81dc84bf6b1b229db5c0ea72f9f3d53f5a6cfa16c4fadc7bd83398491d6fb0d397fd51df3227b853f7605924c0c0aeb1631742dc39b1a21e0bd1e2768822287.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/53cb73da50ae2cdde5f131317858d3531ca7a72783721a5aefdff5f124b4096c916efa7e2b2dd0e3b21bffba88c0c31488527264d26574372111b712a562c89a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/46bee8be9da5243a497d054593154eeb8728ca7774c0f3275cff27ccfc0744e263efe7ac4af355bc6b6075397ea035792b4fa206cfaa89a6872559ecb0e7015d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/bbf7d684b40d911f412bf15e2f23131e4c8be0232934cfb1afcc742fb107fd7b4c2c5d38cf6742ab5dae3e50813ce0f19d8ff909c58b01f5b27d4418a9696472.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f7da3d2dd84fb57b102c94698d28f0e6e91204ccdb2271e9ce04f3a06742d713439c81bb32d77992a9bb3d3b1563d0f835816510830ce6c849f55c79ec79188a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5ca7bb7dc7d1a27e22c07f74cb4f914a82036c1ca16d54e5fcb9e63ab3732cbb90b070073a27d6a82d53d5b7b18fcf9caa6414d1119060eebb98d1989993016e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/27bbce9f6d121aa453d89739cb1aafc1d0b06103a2b298a1c1ca1f82d7d8949d23719005c08cf84d824e4a0e6269b12ff1c8abd5866697bee869b3b109223ca1.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/20f58431e847591f2286c0e97c1b83aef185346d3535e2b5a0352a16fde3ec15ec973bfff3e8b9a4f0d7ff19e27ad516580ca80cbef940127fd98aaae7fbec51.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2661c61d8d86f890a0230c0b43a5e133bbc995a572b443a2c0246fa07fe4554ff7e624ddd90c1c90eb81839a8c3b67baa751261b0f86f20ba57c4634fba241e0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/702c5e1f016cc79983908310d6438592be6490309e94222bcb8a7f00f86e23b7b29a126be22e4cafb24d8a97e0a6a1025f8573309de2ae120a42496917fbb2db.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/532937cf4e94346ff867544f5248edb1a40a41494a731253d0280a505244432f91df90f5868bd73da108ca59f61bd55d914d151bfce0718dec342a1e348daec0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6fb22b70f5e3f12f82b283d055a90d282dbe668062c0148d8b7a30f32f0c2cd6fb50b0b65d96ccd435b4237b548e58bbf96fe88b7b72efde17cd1ac267051060.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/741a67ba77aff12b9fb8cc20829cd47dc90569dc6ef11e21d7050a89612307843f7e482fe8699397bdad2fea34fdc5f7835703606deda8d547f6643d2e4bd258.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4a94c5def028e70a503198e8e5e0744730a8126981dc7d6107bcd18a9545ed50c472bc55a2448875686ed702f0d0bc4dbd9424093557ef5740ef41843730079f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5375a6e859d31113c6bea2f49308d8a57db8fded2a833bab94eed87b48f71c072ca9921ab99cf8b91dc59046b954dd433ebb01d382d5544097162b7c0f59453e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b1c93a980b830e0539ae75431d417c7851e3818ee41cffef75e79a62d7e838138365fb7f64609149e8c2f45290308715e2023a4a0d48d0ec51c64f128503030c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/de828d05bdd8793e411c4e1ca6d01d28908ab8b7ea794886467e411183133a41a93cc8dfa84c57665179b46165c26ca880d439bd442c391e731c62dd66323951.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/073d79a5116be915d2745debd41c3a9c1d05a8f2f8f8f2dc8c9b1b6328bc0af0867e561213f1cd4b02bf2c2e757b28744a280a41165251bddfc4a021f2e68886.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9cd57924426488a028bf3ac2fcc16d11065e9e67492ec647fdc2ba72d2688f5088b25e2203e55c52f0a07062ba1cc41ba2668ed3629b7daf8e8357c917e93af8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e3d3525c424d016db9a718cdc768743dae6545a96420bb674beca9245e473bb43ec4efe05f0ac123d8b52f9d70d48f97e3c7f41f242e8334ec1e8b7084d6d7fb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fa56f4e46a75817a428219627c51dc49789d76d512d558ac437addc696945a6f65e08c05fea5c629f783f2d197efe7c7e110dd8ffe065ebf5803a0994ee8e883.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5af1563512d4454f030e8701833f759d29854e3a89c1f5552a8ccd58ffd27c3fc22d32ffbebeb8fa5211f991824831fc9872714adb72a1c2d6eb46a071adcb74.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/3baffdca79d9a11b778b38c68f93cc803f92422e61c1b86b0db9964283bcdbb9d5b18e13e589ed6e12cecd94499035d9af60e384aeee9c53ec66cf4098eb6b4e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/02cf37207c7f5e45d21884cb2c11c3fa7f8be373a7b5ffb76bbfdc09b24ff7ee984ee63231f2db0c765e994d487b06444e1f9a5768942e30a6081115d56bcf1e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4b2b6944a1fec48c87a4fa2e42e29d23daf19fc4dd95875bb6592adb121564c692a8a93fa094b4f70c985eea54ecad36c3ce6894af008c97ebd3f18271f2f5bb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a7def10ffff1faed983fd2f6d1fb930da4981a4f4ae7a558647b0b9ad4612d8791e2a0050f2643f019be2704aeceeefa6a0a922e5c706af36f1ad6c6ddf84879.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f10c60d546dcfbb191bbdb6081ea33da3f2fd86a175c41d56d001a037647ea12fa70a603585b82fd9e19fc4c31abf75bbc1c90b804d3b96c1791e208d1ca056d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/474053a5c24c67d7667dee47e5234bca12776515971f89f9b3d4f940c2d1d33ff01f5106009c32c5938625e4632f5bca88d26a335c53226c32fcf0c23ec7ba4b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0a9e91eab3d66aa82e74c10bb2844ca67ccfa214a493124c822ca91220aa6cedfe10a10971d26583c3e77c6bc9d7967c58ba2989cc387ff23c17c5912aae8d80.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/dee130ac13893cb9edcda24ee402d46c71692c4cfb4617837d0b297a8786029508c67426ffa6d77e7fc7d3dbf04d7a5ce386aeae6e292ab27e562932465cc8f6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/c1240818d255439e7ccb113ea7bc45c5a43cb84878da734c498b34265131548d81af3a321aa6c81632fbd1918aae5bdbd586b272e9d6d31d0a20384b6a89745e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a96952b0098b290cde29e40d86202eb05c7b9e780b0455a9a94457ab7c8fca55ce41ee57d6b4c4404388bcdb4a2a10395df55aff0bf3dc9a1490553df24ccf12.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/92e8933ec36b9c76d74831557e68949a2f9a8cda2531d91637a2bfb9f2015bc53eff6f38baa68d969b51868fd6ec571a5127e14e344c4d1cec1e720de400396f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4d43c2207000ae8759f2a3e757a5a96fc9a74558a24d1c2956d180744881d1ec1779070ec47049e2ca8c229abddec232c2e110cb10300b3220cb67e15a9e10b3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e46a5b8c7d835df2c07dee81a4ba32b1577d0dd2f771145a5205bd45a2afb1d821ad3ffb7cd65127ed3614307d45b945b5463945876a039b9bbd701543d23a5f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/751782509656b9fada8e5cb637edd9726704c25e5e99d5befeb3c2b4a125bbf162fe28b7dbd27e82e6b4bf0e61f30ee7087f15e1e6732d6ac86d4a4ab5cf1f4f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/852f4fd79f266450d0adcaa1068cbcfa8ac0b420f7f5c2a86412eb6cb9b2282c105a51941a08b6719223c5e51d1d464f1b80f60d5c9e168e0618dfcb7d6f8b67.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/85966f2181b7371133c5367ae2831046a21f68c9a328c1852c069223c0e281b796c27aae978bc46af9426826451e8763ea88946606842493de95387db9619a59.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/091be089f3ab048657d4ebe37a96e49a48e20c5b36cc001c7a2eda6dd5069337c07ca259b73538912ea093493eeec24afdee1bf89804e80f9c962e7cd70404ce.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/db951804793382c84ba378b873c3f91f695c597913bed69d0b9b76227d875734ffca91e00773914ab501fb4de22ceb65957ebef68f6cd850387aea348045bf1f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/66597aa2d1e59e3963b815a9a5239265b096966208e6f4066af00e9bcb9ed4a85d4c4a100bc5d9c9dbc12fc348b05dd456c4861e8e622d3786629103e97180d9.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/3673505b56d391ff20b1e8205b5b3a944f5f31d8edd43d801163bad68a9848a8bf6502bad3a141575f484494070a1ef7ab7970620e736d2f2fcc86a1180200c3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7d027148cddccc46e96ff5030cef5f62aca190667372d68595207a3d862a06e08fdbeed355ed2dd3f8f225453c79a0d0767d54ccb74a2ed760935b1cd88f8432.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/ea0f9d6c5c4d349a93436376d2f4a38723937428cbf0698e0097fa0d98dbeae8a57465432cfbf0148410c7d4c92bceb623bfe46557f48564177db81e13a1cd71.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/3980e75b1a4961660748768686e650a1a439e6fc1ee918f7202ee705c77ad22910d51770227673ba5e8aba547c85071bf5a060bf840d73a95df9eaaba18d67d2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/91d38e8be8b4ddfe129af83ccf26662521881ddfa3640b75f3dc65340af63dd2c81d44dee9152f1b1260bc5cb749844c53ec7abb6602bc6c64c62598321c52cc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/976e93bd7691dcbe1dfa1da45f740b39edd20e18a75990df0950e1d7efb00d2ae1a3ba5ce3ca1b125d2dd40b09ccf9f6f701568702219393902d7f7ae7b08dfa.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a785da129c0c77fd96f6cfbccac410e2ca982cc74e76cb3802690329c3589a5c697df835dd6c0ac9c2c6281ea5168cdd1334e129b5ab3426940689930c383cab.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e882b184ff18496a2033fbe45f462e5c5d143cbd4e804be18330fe2a26d264141c77d91be98aabc7f269788907ed0ebdb1030ffa9e4643b51c167d5fb818856f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/043f617f1f78874cfec7f6f4a667bf994c133b31446c187c238072a202ce89f521a4a75a283fe40a04bae60add804d5e1f485d1d722d0b8b114bf84420818934.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/525e7585a7ac19c0e7a943c7fe7788a0272cae1416521b97e52486ad14e5e36fafb4abcae306d62d5dbc9591b28d3a66f8fa9f6d3116429023c0463bc8b42bae.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8aca10437e74addcba98e261ea8f27cec1209bd5222f7d70a652e1831a510d52ba9f8defad2b319fd2ed54719da0b6ba8d070771ec647cca91b1e7190f21ddaf.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/22cd5b636ec5dff786602f213fddd5a51321ef06d4e4219ba9404ba99ee0131126f4739b8ef56855ee5f21d598d0ad7c6ff4e2fc6fd42b7de74794af8337fd09.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5a87ea19f6ae84a0853080bfb27e0f9ac59f087d838f40aec86124d332e04ac8c654924ab59a7333270006e21bac8f388f2aab24dc378b9a96eba2a87ea252e4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d8145b2ddc747cb974c6063e308f1dfa321e46e39278cfacea06c978403d1200551cbe7d40a4285fcbd4dc12f18e140af4b5cfc01f9b3630d169930ea7ff0b89.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6811c7b8eee5ead82ba6011e5582ef162548841634d09d21f5f85eb0efbf30007c2324574018edade9cbbbb647aa146cfb135aba636154c38f1b8d299bcbe233.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/46959c74d792b841bf0df6fa6d6cf4bdfdeb78be191d991b88459eafc8e5011f7844630bea948f007da94bf29091d16f02cfd8a78151ce32b18ea536d8a6fe4a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/929c6a62b98addddf825752858061c6dd39ed2a7258a54d6544fe9624369a41a68f789a8f34ee16ae065b693edb1ebf8d8f0a8bc643e3a818faf034a09febf3f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9afd972d90e660c31e4b1da5995d97c007e2811d8ab135050d830b327c0dfea10f3584554953a9b99fc573c638f618020d5e94ef307e236457f7b0d0ba709e85.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/44eb3a0558f7073d7f339cec6304c9007a0ffb044b43014935a7edb2d30790d521f33ec5dc21f4d7dd4aa37f4309192e613ad9588b20161078231ae9140d4af0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4a5d47a2ca936208a75ac75b9f4df20514ed82b265a0267024f91d7ce15dbb83f7c41bdb20869d32e9b79958b595d6c8f9cd296314d0f4ada7867514d3c74ecf.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1da7bfa0de70a3984e5a3b64d16a5b7892cd86c923d6f639c699e5287d2359d4c1754cb27061c78436012ca718fa0d7b3b794977a4bc15a27b542bbce354f91b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5f53d11dc12ce39ceab4a8f955edaf0974dd96ad7f1b716bad9d898291da10ab79c97ac20452d018eb8635e8f76b5595b349502c5932c7dd312dc9d405ae1692.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fbb369ef96d015d07594845b6e90308b6eaff125f7e1820bcf680591913ba7db9df5363fc17de34d8249b051d99a7c735059f40ad2b2da1225fd63cfe1e4f30e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8ba32d5ba9e8064db853646f7225e6946fb175ae086cbd39556e34dcbf12805688815692b99332e4c4d8b8fbb053e898d8c7fa81766d181445e8e7501fe98d9c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d9008ecc6c6a035ad10bd5178bf7b0cbc5254cb22f6114cff493feb451fe44b611b6b0ff2f35acc12d0ee319ee77ed444a1eaa4bfb3201464cd1382d628d2f9a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e5dfd9e19a630bed0ab470a3aa8c1bb51bc6e29d498116ce716b54fef7adfc48255fc1bf326d474bcd6c9b959cc2fff37606781db96dd9f19630fefe16f851d5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/395f33d6bb4f76206418b1b4ea0e85c17053826367613c879b7522258dc452de303ef82ff83c9bb25d7443b37d80ee5239e9cbc8561a6b56bddb97858ad84f44.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/cae64875f52f65a658165c5608968f10efadae402a06a036036c50e4bca442c51dea019f8e9fe035395295ca7cad4bacd9ddc01124b589b732b978477b484a20.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/84e9e872afbde9df7bd69b9971aa2eff813e360c631481f8f4a91025a58f4ca013eaf16b079b9721f247cf35f6041818c9455f70231236f1ce6ae94b338a784e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8b34f2b237396b43591561c34b0129ea46ed12d1a22603a2615094b36a406948386d4a5e3d239e202204e11fac4084d20c9626ffafb4eab4ef84aeed8822a929.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/40394be022cc0577fda17d3e754eed0dc2c3a053a1e0d5a8db90a3fccbc09f19b23e90b2178af047fc9cfe64968e5a694547b4bf9106dbf5b7efc0f35ccb03c6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0fdc10e061224a6262d3c7f9fa480bba30a4d5a9047c419f0b4c7afcac6bf1243384fa6218133185fb2f505821786ff35ade2cb0e585f86ae21c862f00222a63.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/613b43514e9c15e6a4dba74b1fdc97bbb18de5872681fa0e5145f34944ae2ebb4dd2643465136807c78f5d630cda211d5617ef6253a832fe4d31de789ace10f6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e3411d340f1f1d2f2e09b219de8d7af8d3085facfb0cb76fb8d68ece83b91352ed717889869af811caff1bbfd4c4e8ea498f9ae66d0c4fc5305999278cde60e7.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b63fbbb8ba1934b27f2dcecdad7856deeaee4bd30908475fa41c188fa49606330503b29bab10774a1ee4e360343ddb8c7ffa02d1777d5381b0e7dd055bcfa778.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/180201ee3b7d7e5b4a925133a1064fa0579ea50d615d737bb7e8b42e0ef7da746e9f3b300fd440471cc07afbc04d97f0f9f86ec24010183c1e41f17ffed72d46.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/43f95986fe44bf9ed294103b20d5fc2f64bc93c0fe2bcd0fc0521930fa391e6ca9d134fef0d74bc216a125b0dfd33fc3124da4f6a60bbf5a54fd87eeee172be0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/544f6f6d82a2adf9f814b695b74a9e9281452633ca7968a28db428f4ebf0f64e46f62bb5f0946b2ec4d8f767caaa4b44c28e6ae236a07ec9bc924f5a8cbfc697.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/89985e8b70ebe93ac18263e6f0fc526d4de73f0786142ce66327b78e05863af4308586b09c49f3cd639cb9bba3985b8a1b54b7862d29c92934f7fa24a29ca32e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/952a6ab1b75a0f2079c75c0b79ed6d3326efcb28bf9618fa7ab58fe22b51a44bd07448011794b4c44ba78fc718d3ea1765f34cfd8d824e284c1c6f09f210f83b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4f59adfb0985e3b3d1bc9717c03bb100bf2e91ec9c2958bbcb2b741924fe9d8d762c600a4b9f0962213f4b8b8187781c98f2fa2460981cdb88abf3550d763369.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/61e61815d9c977acf860b2af4eb01f5202b7be7dfa136bedba338f0f7fe75c0d8ebdf082e8c7b1203d4b887e60ac315cc416dc66072638b2de3a32dfb28feef8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0235405604f73d5ba9500dc44c293e6ebcb7575f830c471b5d07028ecfc4f2bf968ea1a2bbcc7b656a6f1cebb3e10eccda6bf344c206a0264dd73dc5e0dee937.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7be06cc8f85b47bd278fba69d7153ce13f858aedd96c6a0a0a8cd6a9eef0a1419985a6cb3364769dd030619581c8a91f33500f99218e89657ae1b5d41992bb04.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2feb7019968150c5d6b5e3229e7ce986b2cdb2cad9b5e753d0043565aaf336826faad51cdeaa3d4b736733453a21a3f2a0ecab5b1b01a43109a34373720582a9.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2d3f8e9dad2c34c504aaa55f2dccfa8f0134ff24027e4d3f2b90657c463e603d65870f70e09912334da6409d64d0d3e40f82f7a7f2be27bbfbca2cacce144b86.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/78a7be4aee21fd6dce00f0b58953d2923a3045ddca6ca3ad4965d3d3185e24e603b32768cc7925f1f3cbd2119b544cb64276718be9b84ea43e6c5bc862630cd7.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/982e149ec718a80ebe11a96e8abd8d7e132f12e3f7d29d73983d7fbb2065411ddb6933eb7feab4d264ddecd3ebde0fe0ce05d350ebd25a9aaed51399112b5d63.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/dd6e17915153a89304ea6d2a5808c68ffcdf3d806180d71df82ad749e6c347a59dd4c5c5b6c1a3151597d4c02bf245c244d41b68713bcc02e439e16e64d7cbba.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/357ac99aa10c2b4d11e11bfc1efcdc42e0e4d2f2dba57c3b7bd8475597ea376d459d7853c95ff0262b7efbfd00ed7514124711ef6c56f0c6faf46c62aa7a73a8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/57398d81004b1b30c0721869af1508efe13ff2edb7f9103c2377ee39a886f18243b475718616e713a76a77da828870d9ad5aec86c5cf8a3190ae5b3d70a8ae5a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9a698a4dae12d4f46578b8b18031f9e064f14f68e9bc1a8e0b1a12c01765a9551cc4f07c6bd0afe6155ee4c577e8147baad67e51d7d468cbe238db8307c99a1d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/90a2b1b8db1b3df64e91cbd6a55147f27934b73decca69edb0ef634c45f5700e8749ccbddb1117ea7faa3949b0edeae411fe70920aa8f2f0465d8f3720819f08.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/67202cec5db949be57120026607f53b5fd386aef8d129e5ddb0a36f1c6bcc8aa08233a9e2e93d8ce3624b9fc1f9c89370687425ba66d80ec3dafc636836d929b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/35937ed14f46829df11844213723ab374faf2345cea77026d97b8bd3b6ebcb2f8d4af20bc8336f28e2fabf86109925727d4dbdf556ef6db50fb50391937c7091.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/caee8f59fc5c60452fce34de18eda083be241c59657e40196f3abeebe50a31b3083037e1d176a23e8acb8149cfadb96fb11e4c92416757c3db290fd9fb447037.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fcc1c5a147cf248b74680c4348bfbc3042cb9f9737d1ddbd77f1329d0d465c31ab42b1c936a41035f23ef785e6b61fbb21852129f0b530758586b55f97015037.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/864a95fa2e2a6f817447f21c660067cfef0adeffc22fcb7cb76335001875a5785dd58fdf04c5de4bc591db5668bc5227cf95fbb2bc07b0eb753e9b79d345e0a6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/226ef2bb490cda846793a2b5dff5006ef496f22ad881d1e513f089d1c23468af32497bd7b977b54733aa3c633bffbe821a41163ccc0687de4508f9d564ad686a.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/61af32235d41eea875a6f25e8505866535e70b7d9f374cdc78917ec15647e00d4cd1536bc19a2fa9e0ff776968234ab0e513563641b7f16f9d10ecfe700183aa.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/cdc6b769650fcea9693627edb0356a0b0324385d7997491742bd0d983f29dc2a06522f3bdf3a7165a166fd05ef5d4db8d81dfd42eb5c8720db3d28bec2db38ba.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d05d1c2cec5b7198717c5bfc67495c745e2574c21a83352786c38edbe2f68edfefd667d0c41fc813981460d46f655d5cfe5c43d58e606c175d42bb48214b841b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/347e5ca0c2c8b51f7d91b941f6f1fb8272e1d8fba77249370a149bcee5df1dd1cce5c07bb46cc52f3c1c113a1aa9a9e7f91b5e1a7f1b1d2d3e5f79ee50b8080e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2a4b19b5a1fb783fba6cbed01598fec0eb9d816db9edcf28a74b94ce005214ef950d3e4051c77f305d1812fdc58362344423d6be41faaafc7998b0751cc4d0fa.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8ff4051cb93f58b4c6604a2a2a5d8d364acf8c9794a0fd263642f85516e8dad27173a87d9f04b773caf9ea0f28e863a7abc77e517d974528c420543c64b878ab.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a093194f766407d567bb75d50c29445c2b1a835f4e5e5a1ca3aad669c935756c5e032b85d191830fbb63042b26fa6dc74fd33994ebf873ac15067a1cb8712f96.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/c9ee84e55a47a37fae25dbbad3d5841822997c4d5f30e083c188c5fa0536fc06d7082d257625cdbe1dcec16f12d447e2c2246adec7af29c38a38a31b9612a62e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b1f3833d43dc9646ac929038a3574fb4e69974d64ecaba082b3c66a15eee7edd3069ab459d57bc83faa4d9338b692a3bb31208ae20f3ea05443106697373caba.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1d7160df01209e95789066e314a9cd6e992a6cc253f8def951ad36f2ea62fd15f17c78ec2c823c38771bf7dabe0cc8781d9abe8cf616b716ea0ad3f4c87cb3c2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7dffefdbe35ddbd17d58e824705c17b0b35f0d19169a5e04ab06a860fa9cb7f12f0f61c91324b12e2ff14922bd3036baab3daab2bb7dc8a0f611cbd054c3879c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7474f39c7bd28aa2abaf8a26a366af1b170e696d704a32cf9f3073ebfbc72c09903bbb57acbe3f0181bae9d5ef75e9b1812b98de89fd4ce62f730b623e14e0dc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d91d6f40f10ef429b3ae736b160b44f2f09f51fa343785c399f43aa4afa3cde0712d27adcba53d58b4b3f68c666dd9d385db7c6d922fdd417235166330e6b92e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/95a58e191b5e00ca8aff5dac66c6088dcb8a3b67d060dbf0478106f39b47f83be7d22478e60cf30d11e34d70cf9e1495fc291ed63c773c0c34a1ea7a21d1778b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/26defc1b44ce1e004efb2720a8adb8cb5a74ddd580d52395fc9341343fdd4cbaddec87003ecdf7d14299bcba17848eb4aa165eb9939aa04dbe4204ac493eb45d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f52f8244f3bf3d4e5ef8d9606095444240797073e7284c18404737e0caa1c3da6d9001bf8c751d55ecf19610bec8f0e4abc1872778394e4b262f07a7fcdab555.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/547ab89614fb2f95655032e38c23e3418d90495afba390c4c44578a05abf880086fb7645c64313767e9437b90fac909b5ae80920e4b3299c98fad7d68598940f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8d6fd8aac59f2c4dd9e88d29740ede2a8abbf47635510a675f1744d1eba5a6da2417975689d53d97cc6c7131d35c3edc97a696d3431d916ea07093793eccaf70.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6eb0f2317e2ae6e609c137bf487ecd2a2ad09b0ea2f7a39c1c93b08c34502f00e8026757ba31ffee93322721ca22710607a3e5aa36a69806c96e2ba49c6c15d8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/145ad69acda8c8de8c1facbb1722645b3dde82f9d7f299dce48d23c869814830093b6e314b9dacc4f2ee033c7f4d0b7f5b219e09d2e2922b0d2806ac3dcb13a4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d1bf2acd8762b3e055ec2aa185492d9b2f0280c0ac6007c79b2ab17893c6c6dbf14eb740d4fab41e3024d3b978d63ed67c1defdf2786e73eed372f8227a1f199.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/afa03af2da4109c4515305daab553365269f251d21d717417cab4bac5befe664533c532c18032074f37f3d883490155ad411d463780801f08f78b496d56070c3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/73e402b3a8dc8d3228b80cac197dba5250477a289df5e1759e2638b381485cb1832442ce46996250ae91db484020583b7845a5931e5e7caac3d9ea6d9c1a40d4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/45a73f1bca3a4dd52fcd12a681b67441421214ca656cd8dc5c6d569f2c211d42db4eabbe2adab587f466c92310f05660e46fe5852c29852474c436622438620b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/541d232066bed81b70234eea6742c8edec48e30a0a2eb145788c917acdeb818666acefc5e9a969eb6f18ddddd5b1215175fdff195332d8658d1ee8c72924b125.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/953a4b348cb7fc7efa066e99ad84874132bc06aeba7c0a744a2d26033f1215f1fed292ddd8680b65959040ff470c72a1652e95b612d7202e755b2957ae36100d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8f394228279c46dd300253a9f1bcee9fda24c9eb7cae33f954a1ebd22f1d69a900004ea91ee7b2fa6d465feeaa2261b3d2bb45f74876dce7bcc85048ec682a3c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/873fb34dd23d3f26be24178546d1f51085fa3ff8b2de4ea57b2e547b2886a436e4ce21b450b213a8992fbf23263a3709fe19459e3dcbeb28446b18c4b19076cd.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f1032a3a99e0119911a48d727926ec2861a53ff6008c6ec2e1246deadaa81f4bb35f77d1b2a3cc14a6f7fc233f4713d9a012e8a3a6c5d6efb7f7c27605e59c1b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/dd7c2cade2a3ca8c68a8759099e2a4a544980778f8d31541b86bc53faf3f05beef91e1066357e8ace461c42e1bc9c898d2c618f1a96d9cc418c28edb2dbf1d0b.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6dae5be18cad183a08cba7b0ba5c6f3f05d95a0e96845e7dfbdb9c3d09f1e1a947a79e2f26609d8c5e1c5ad21d6348df85e94745f6451628aa82e365647d5c37.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a06396d0347c2427b7b28f5482282162e8843e0832166749e89c221829955d783f67d575c447090a05333cf6c7d4f7e127bdefbb8ec9b7804fad4095f33c551e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b19627b2c9dbfcfe8fdc52bf0b73dc7717175ed8e3d53bdfaaa6e91e244e8102e4bb6035fe206405dccd1bcda8ddc67b62d70f366ce2bf275b473b61bcfb04d8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/47cfc15b4a892a3427b9932a15d495cab98e0d03e69a97e984f83efd5d68a9df054ad38c7ba92f32918fd709b4e82fb66fce9a3a89ae94e693a86b123a8a86dc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/ca35dc30452bd1b9f2ec5cb565fe5cdc4254499a39fe51b1e43559cb0fff10f0381b7e305296b47af2b871809b1167832b5b4bd20753508318d9b93e0910650d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a0709ee104b0a701e38249947eabbca11b1825d4e99d2fa21698ab8a3f7f080c094d120fd012421c235b2bc75aabbd5e374604a66c885746e86e1b4db42640c4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/341de7f72f713f0ef16792b18c38310ec6e815b2955e6fbfc129863a47ed42cb4fb4f6c8d4769e7c93a5393b2e923c029e18e474ec3343cbd76513e64bdf5107.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/c79135d9f824af11b1c618c491a91e2074b936275e813378a9f4b927c6a046b79047b5308c8193ff7124d6ab02111b4c4988ab29dd55076621bb3ba8c094c06d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/9654dce4be83a73cdb228c4b9e8f0a7ae35e7435143f3de559136af49ec1243a8e0118be819fc1e4434029c2ba71e6580c7cbf79cd8c5bee5e2f7a94d12dc423.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6a2bddfef05a1cda1d8ab148fae9ecff084af4b3b1d71e40dda73123240c75390cc67663a4a774c30d6dd2f68f8ca00cd76ba7983fdfb4d4538bc19f1cddba90.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/a3801954d82daf7c8ef15fe836b90ee954e78bb42279d50609703aff12b3476dd09380ce9e208e442d3ab6b984268dc49bf6e7ad12c07fe69f6c501efc00fd26.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/22161635bbd979935705314d761791d45d68fec493f0a9e7fc02c9cae7d468ffe29dbc6fb51f5be01d08fea65c69e454a9fad08ca93a4610016bb041814c89a3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b2a1d45ce5a5074dbc157aa49dbe4fa58f3e0fa15dec0b2e04cd637f7a89c408b30ee0a6f5a30ed391d150c34fb34875963174aa954e80247b0bc77b7fa222d7.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/dc827a298403a038af63dfb5a186dd6a73978565ba380edad7ab74583ff32cbab296017839afd750edc1f007dfdd8b54b571c71787c9dcbf43bd25598d312512.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b6b7e05bd8758bed90bab7ffca83f7d617e3cfb6a3743fb603b3ca1613c4c27c6ffd37407d384e416fd01fdd4239f2ace355aed97d3a144b9572ce4ef5d01373.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/af4f80fbd904a3999287d5c9bd4c479f239d7a3388b1502fe9ab15882fdabe911be9dbff09dfcd27f5f0ef6d38321f65a11f6e0ad497aae3756f3770750ad899.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/22f3ca24cf9c97a9641c5666e813c24b5ddee70ce1ab9d7ae561b91ed3bf58f8a3da6ab2910cc54129f6f2532c4a8d6cab33800babeee477151e00f83cc5d1ac.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d516db6f8565accad92a4ddec2d99d24c2a3f310d2c9df5f1a9849d189a4fc8ad042f501a889125628e5999cda2b9baaad25a7b01e19822377722c92c0fa0ffb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4bceabec3ab3c8ee04e1c109972a9ef8749f359562bb0d0018e534b33b186f85de82b8bfed102b30ec072c2be2a53502df513a6b1dfe22fbd9c185840e31391c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/81dd4ec4537afb3c5250061c5ffb8322b3fdc5064ce5db213cc40d22b1fcb60500be7bc1326da0d74e81bb611ebf5fa792bb3dca2ce185acd7f1540eae025a0d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/809e3385bc91213a4a84f1217edf8bfd4d0a23bfb8a795bf69d767e728c910d9a503d85f7ac17dde05d65573aa6d2b16097f01ce740fec10b3ad73459b2abbfc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/ef1c96b5907637ea0895e7ed705ea9312b9dbc07215e3b911c149380ba4e3f7b07d4f587ae5eb1036f62528b055a76e83041e8fa407924d86972bc0d52098418.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1e0374e00a37fb9f426e3574c866e97b254ac39d366667ddd0fda064d7916f1781936f173f9ba6d8a4a3d4c6d6563810e09c37fda7d043a94450ad7bba1bacdc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7da1043cca98f4151c93a514cfdaa45d1d2ee5027e15dd6c0d22c67fe2d291301911d85694c73b476179a9f927f243e207c786cd432296947f43e9060a579358.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/3061b86e2fcd71bc99086ca85b00b4a4dd7f4d95e787a9c73508e5bdf80c61418b93a72da9dc46e3628e264b77265c9d2222926bb522876e22b8a66a34c61a1c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4646d9e2b74646466d2bd4c5d4b3861d9df911b10dadc20fb2dcbb0c053fc41bdfc1df3b75e3e010e57620ec4356217ee7f0cfb56d84cd04acebc537b79f5c37.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b419491049148b9e3dee9c0c93b9ce0102b988c4913b6e852840b0d4050744bc964927b7cb710247bcf11c45243eec7786a63e881d598102a0b71aecbdbf04d8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/01149a055891fabc8ce23689a9da0a754c304b571b4fd05bfb0c5550602d5c19b7caf2eb50cd252026aaaa2dd07ea50dd10ce4a32fde4773dd50d2d58849b130.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/37a8f54cbf1886ba7ce0b93f6efb9a034e368c12dd4055a9e333cf9aad9e5b6ed020d5454ce48c6061ec6e3f88dd02b6db764a53f11ae33f8aff073fa5560dd5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0c26f1a735fff4fb979c49f77e9292298df5333c118629833f8feb2dca15d25aa3ced3d4e34e09cd94ff964ebc94d1e16167fbbe2e81f6c0f63c7083ad6f38bc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b3c7e9650470a5a93b942b9245d117d68e323a6d30d4dfaff75e5377a81c9c80720ccf800b33f87d7ec3eb29f2f40ed0cbb5de9ed6a96ee0766fa2bc08725756.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/465e9d860cd9f66b41bfb1a6a1db288c8a87c62f6edf83874f38e862d582cd9d06b871ae446d3e9acab7decb075580aa0d360e9355a7aafb263ac34067c8da72.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/20160cf31c837195a435421a4a446988bed3501d3d96849378b9fe1002fa501804fef3588b6ebb36188b1645f002b2cb7678c4015727b96517e01ac3fd3aa9d3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/ee61ee10829cf30c1ae83dce767c205443e1ff216a887f2ee920e0c2037ca8abfcd1f52d05eb6a0768cbb07258f56e6e8b02bed866571128a1e45c1796873227.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/f07fec7c7b0f69241f6d37ecc828887dbedf7e23ceddda867262e2385c52451ac3192fa6656fad4382809de2530d8c95073e9807ecf4714556929450d8517b01.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/80f62fea16b3fd3aa283ed73011ace221207c221f4fa1ae1d19c2083de069e1b8c721d3f186abfd31358f60e23932fb31bfa6e5aa13f8cc751cb231c02d852f2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e3ada55c1d6991aeb30076ff27383049f19d5f3bb65d71ef08f2663a5e998a87b36491c6d843197cf2e91f7125a6d73094e95932278a0715b0553dcf5fb88316.mp3
# ...
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1e9cb8afd7de0d0f29f5c8189ef25603f1a9c3f21ceeca036ddf4e5f6dd62e0d147eeac585e9e6f27d3c3a584913cb8cf8facbc09cd32f9b57348b1209595eb2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/20bd18acf84ad0eda3edc2bd316af17b8cf61e1e5357bcac45e01e1710094154fc17b9e708b959a502ab31c782e2601d792842b53967481e98663231ca188202.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b55d6cda623196740d37b45af5225585a552876a6ade515c7e9d50e3b4002f707d3b28e9074f9e7e3f55293660354520323f166e41756ade5d636321fbb7a1d6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/26dc0bf7f7ea584424c8e77b9b13603dbc9e16a34cb0810c86146b0d89063cb356ab35e9f65e1155af447bf65b179ac4216d3768b6610387f08a5cf9c2223818.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4c688e8b23f873db7140d4b1a0ebba891bd6b94fe53ca97c02e9d5e64df6cbdcd7fd8517ae6db39ed4a54bc020fe7dd7de8dd124c4f8f17e4196d2534d6e9935.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fb3e4b23d7a847222a9384c4e2f23ecdda45f59b135f48078f96ab5f9a927c10763c03d34aaf413e47840ed77ac48c187a38ad291e468532da4ae9180f35a0ac.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1e65fa8700a30f8ed69b08d551fe86bedb83e2d95f1788439822659def22eab6ab5f441291c55d4d1ccf301deefe53348d70ac27d1db7d298bb6252b76ad16ca.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/4a1fff4ad9ed6ac4942c6d85c859fd681f47478b0df077ff623d06dc183bac93f1ecb0916b0832fb9a14550eaf2c06eb359aca288f5dcbb4d5eaf2baa68e1ae1.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1908c040eb0178c94623b523887ab53d3b9f5bd1e8099938f6ec53f1cb9328fe7b2cb30eac8905756d4d362aca7f5fe9f29a4e2ad3c1546bb54aa34eef69f67d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/32499622c25515a3a62b3b37edc6d76cc46ebeacdd58e9db67c3aa4ae3dcee65415dd3b39889f98880af6496795b2b680bdcb65939e93adfe6372c7dd7ffc711.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/21b034f4daae507b1444f2996636e6572b5008d3e31f1c4e8f7293f8e937bf6e99e77dc463c238847f15cdca0843de5bd980c2cb78f7419968353101c9a36636.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/959b88bb4a127999052bd4318268e38a058d4e443ce2063bf4b4120da05a229d81b8d1c561377bfeaf8a4b65f5244dc7fc436c0b0274dcfbbe59bf529f3fc778.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e64795b365f47ab6de20d714727504dfbd6b8fd7b8b7d85efd26ca2de41dddc24ab3780522274239e3e193deada963a5a102fba36d36da70731eef22eac3e250.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/719f198eaa4fecf335d389b56fc1a6aa399c7394bf626b34163398b9ff3ac3d1097f8b4ae520b851d9059fef080ad4e0aa033e5d65db40b3780093514de6df7c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/dabad3aa723f5d02a59c98cbc10e52416a7f5f73c2c46dd25448c605423da3face5de95e467b9ba2c25050db391203cd2a8e7190c5ac93c6eb135ff6967d8b3d.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2671979c60d436ac872c452c4211c1ff6d9aec9a15a9051e30a7b1ce921435a6a98135cdca50015e97e2879bd2da5a3f87aafa0c75571bece9bf4fc8e0d09b1e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/577876419c87e882427e67b3a54c07edeadfaa636ff30d1d93102698eb05887e81e3914e03331c094c24d30a9e3c14aeb0513b1a49ad0539b017ad3b09a4a342.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/521b9d7eebe35dc7dfb320858eb0a6d89e3d76d9dc6395f722f45c15f0b3e66601fea937bc3597a6cdf8dddf7a8bf1c9cd273cde837e9721cab18ac2298a3393.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/c9cfd348899a53e5e4754e7411164dc6eee4ae0236cc25122967264e067d728d554d7cedb966324511d38d6fc5f1c39cb53887588b41d1a1925d3e2247a0a56f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/84ad596fa008a455b9ce63c3c2ae940f162e6f7740cd97394417776d18bc2d9bc25b86f34f91332c79a75770e0e0c1b434f4e78ad5fbb7f41fab1aef3be10d23.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0db34ae22ea7c982c87f5caeef6f3687eedb30ba10c94102522672f19b01896a3598bfaeba2e959d97f4250d08bc8d3babf3cb366b42b40b7fef6702c90ca904.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b8d0a27935e6b41920c92d9375d406bc1dbc357167132db404242dbccfa9dcbc713205a735a8e9057d7215a19affe534a7fcfdf3c3efc86578f13b735a0ee786.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/027d12b2a3bd049c026d2103b849de47076a785f76c174fe3787dbae022d5444d5c6117da028d462c5c73192f81df572792ffa26c6c266154df25be439875290.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/2a3e8d89ad087bc7db3972e56ccf02ad632818e177629e21d22c2df6704d4431959ae2bc74f67df2ecf55bd9c2a1be4a155d4adec13706da5f6f992d862deff8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d2780297188238ffb59f6d715d3f85632d101be12fd52abd7a8993e1f40ee149357f0d4ec73098b8c710078a9dc1377eb6b927cd1f401b27fd9775230e819efa.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/da42b20715594b633722d6fd7ce7121ede2489b1ac015b871c713cd0ebbe23c4626ab87d8e370b0cc6a76cb22a47430735fab18fd2d4785db7335f770a56b9e5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/62422d9a4c5280ca6c7a228158c428ad8b14e55a345aa4c94643d9bcf15542024e191852feb80c3709662213e6c2f3d1ed6e38cfb59325169cded6c9e6303c8c.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/13b37e04f5a97e06b67a6748c5b0c2678b0998f357a9e67f8c144caf3014540d3a5f6ca73ab9bf508666b8467f0543342f31c93427b80ae5b1decd79c9c6c9b6.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/cc4fa37430c463958bf21e10b97f207f65de40648479cecb983a577c7245168f73b1522a4dc95a7fd62901eda58b807bf06aa10068263f500bcf7a0856565bb5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8f665cbd659caa4f6329dafe1ddf3be2aafa550c887ce5321c6a9d762ff718f06248271b17355235f385b20c3df2449e87bbfd0004f409a00fe3df09fe6c3cd7.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/08bfb604c73f9ad9c73ed772b5f58e97ed22d97c67570541cd2e52d57f7ed4288ce2033cbf03d057009d032aa146f4fbd81bef3abed08d03f791ee5c80551af0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5aede2d29b9b09d76c0fa9e9abbad71fb4ff36903b554ff72a90115da86466d7d2773a68fa81bc95144d972c896bdbd3d1bca3dd1b827630e9583a582c1eb0b8.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/8355f121ffe5a51a5686429d744d51b82fed73424046646bfc8293e17db068c4f22f4cce21d7ad6d44f5881974a06c2774a572acb50a1737764743da6cb840ec.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/1ea6a6eea4b8a298eb75047a50bf92d782f3cd08ab555544c63f066d52cc76afecdc2d4889777a92dd2e271c376161e432ab17bbcfd16493dc059c2eba145edf.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7e7e09ba9bc72ced197d71037f81a04922af5630e61a243122b8f7677fa4a72a12aac2c4d4c3623cb7febec4c4d19b1adfc92eda6086c42fd284f9ea26bdd6eb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/74f6e1790285e871010a8e36a0d767e590800fec905a6d4ff53b1ce7c4a3c8b780fe5073d83c55a116627161a7cd3c7981da7b893ac897df8a74a8bd6f7e484f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b18c4efb7b7237668a056c74b3434718784d3d1556f21d5ae40a34a4fd1ec31098f3d0263a935453eba3c8df8f1962f3ffd1136c5c1b4ecf3a1bbbbfa9cfd4b2.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/6bf94011198665c2abae076c99a9beb9964c75bc0748dc5d1775227d4df3be9687ca4600db555ca092b337cd6485cdd021be646e8bfadb8dbb4328901c539af1.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/0e36a178dba1372bf3c4137d17eb9d776a30456346378d9b15b8573125eb7d3e34d88765ff706178cd8e65d5711e398525a5884f92d803ae5e2e828834edaa8f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/fdb2c9e7cd7bc50f3cbd16790ca324360c9c03dd57892fa6df3e378d981e060d017a833fa2bcc6e8a520429fa81ca9142df43c356d4477562da2d2f143d3222e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5ffc00959558587a23bfeffe7834523a04aa1e2325dd239d46aa8719ea3cc1a55347bfd1051008a66e3022fb39df7fffde046d7f2abbffec7005d261b37cae80.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/077175094eab46cc243dd5ae7038a4f24918e1e2ac6fa4adaa83bbd83f92ba1f44eea741bdf3ecb07199ff474c7f39fabec703d29f9bebcd739d708555a0279f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/bf093333304df8b47694f0d75478705fe3fe534a2ea761890c09f97cef32da342bf9e51ac2e89f9b5c0019f54f136c1de4a8b704d4549ef3cb3353d40b665813.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/123e33abbaa1699bbaf0aa91eff013a054c9379e8ccf1096173e17268a14b152bd9a11022de0ec6f57ff640bee54b987ff0aec1603c31a256d3bbb34c8e34081.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/017cf3c4e694e229a8acdcbe586db326d50ce9b47621ed5227cdfe799bd1cc51f9cce9f773799ed63fb189c3dc546f4e2ce9e049f2578dcb2227f36b16eea8f5.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/eac42fd318755334ee2c6987f8a95c11ae767fa694af3ad41814dffa028a6b6e25233e53d82273b014477a0366f63dfc81e1e4f4a1a8b4442c7f2bd4fb5794d9.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e88a5d0388e6a89f61148391e583df4a2b6b3905d2d74e17daa02b52d0b9ece5056b776d901413239dc9d8558c9668e7d895b5d9865618205831a480fe4c0182.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/3e32a7e701226348fa892ff48a3e45215fcc09b0091e6fff61afb38d2e472f1976f468bbbe675354d21b7400355686d5c8827e4d30ec94734c8556dd2cad0de0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7fef3bb87a8ccdb64f5c14e5916a40a32aeacddca4d94b41cb824cb137401b6cdafe46302ad5a32d78ac97e7a4a7df63918c36763b5bc8bc84dc580c8a83eeeb.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b2e18d33cfa7ba83c6397fc41fc311f8bc60857cfc1482b3ed2b17e0c3a18292ce88165b25584b2461a7914d906dfe07ee2f6653afd05ae362bb386150082317.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/7c5b16922d4880216988759c723c9701ca366ed6a2292d6fececaa7ed3d19b5181f5eb19b1b8eaf5e388f7602fe1ce1fd4aa6a09d7bd7c691dc59f80fc6734d3.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e5a02900e9bcec51957a844aa8ae7e4be4a1c2a86efdc3a8b2261cdf1bbb6781616c26c4b32c2c183cd1596b0f7d6c9ada85f9df193e00c9db1b1ec4ac53be7e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/c507c5c358b769d59eb04c64ba21b4c24017c4ff63e72a3857b7ce7cfee69ea5b33ab37b20e57653fd4074a71173fbd473a764cd637cc2adb4063df02e50234f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/926545437574c31d7eef761b1be33db1414bdf74d062c7c91dcd5831fd9462b41fd3ec0a6899420abcb68ecb5fc3b3b57138f4bce306c2615d5d3275b8213a0f.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e300ff3ebd9d87710639794c6dd7429e126ce5209491375f109404ea3160f215a5fa213791a9e5c5484aff1c611c2a523ebb7ab327b26c26b82091b3091222ef.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/15ced1506300fa9371bf3209bdc29d842df8862a135c249c275a531aca6cd5d40f1891baa9be524066831265b3e1f1e77659a2207260f33f6610d360d41b34fc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/edd8293db9e4fe2139dab353cbe4cd676f04a9dc582a5ff6aa5a8ab06db2f17c69847db9b458b80791930cf9b97338dc3c871dc08595d0fa99342e68c82331fc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b127dfe9c1f0c995678ca80b2cea0e52818ccda6420aef83257b42e7c22abffce08974c3986e0cc716f0998a272bcc4b7adc2f151f27c87cec444be8f3cb5365.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/acd1c0ac104f27eb03496a2ea71e21c891c0fb1e301ce3ec1a0e93495260c0d3b5cb7858f915c54fa32982c26698323fd041bae71de798eb8380a1eed9f818a0.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/5a8926c34ea6a6905ce3c1a1993f26a00bea2199c30a4c1d98189bfb84735e27e4a856deb857d27e6470db565a5dd7ff7fc3e008b142aad2c272cb3c40aa6ff1.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/59e41392e94889ea23c59bbc7ee7c9a997c7eb7224ace5e77410339236b5c1184b8eb1a7c92147aa291d13093533d949827084aae7240d64c072da4410679bbc.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/b3c7918405027655a1e695f6ff1ef4e0bb8ecaa752da8d8f62125a42020d992f14b15d6d5688731622eae914c3290c05ab2eb3a93c391349bad0be45b719a846.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/96e86ebc16656ab5df45a8f90a6dc90e1989d5b550d5d178884b3911575545a8fe292895b8bbfdea63c4f9414408df2b0679d745cad500531a616b2253cbcb83.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/e46fc0323c90292cba5e11d462ea8219dd4501965d391894a795f5761119d3e078580d7fedd482bbbf6541e679ec0c56a83b78c0a42fb6381af2fd6a1c970aa4.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/708f0b96e881b7d7e3ab4107ec3193045863b9bacac15cbaa6cd7aad3c4abbfcee1288b02ba184d5170b61fefedac6d5c1a166061a68bf7ea0357d6f74dad59e.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/138c4abf3cdafe5238907a21f771942fc36deda0bd086a89ef7821d40ea510dbef8f78a18afc02b053ba3fd60df97b1f9e3f9bd7360f66416918677da7768d99.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/d756c70a90746fe298b1c848a658f337c05ce54d7dea43e15d09e0f109ca9334474158980693b76913815a9e8982d6033c096576a5d8f5db5e7e6dab819aa749.mp3
#   inflating: /content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/984bcc57c15f92640403bf87480722c20a5ecd0ece231d5832718dec7ff0eadaab55b7a9c7929b068fd7dc944b362f44c5fa0e3a444e146c689854b3f47ad23b.mp3

# %%
import pandas as pd
import numpy as np
import re
import json
import random

from fuzzywuzzy import fuzz

import torch
import torchaudio
import librosa

from sklearn.model_selection import train_test_split

from datasets import Dataset, load_metric
from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

from transformers import Wav2Vec2CTCTokenizer
from transformers import Wav2Vec2FeatureExtractor
from transformers import Wav2Vec2Processor


from transformers import Wav2Vec2ForCTC
from transformers import TrainingArguments
from transformers import Trainer




def seed_all(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars
    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
        torch.backends.cudnn.deterministic = True  #needed
        torch.backends.cudnn.benchmark = False

seed_all(13)

# %% [markdown]
# ## Loading the train and test datasets.
# <br>
# 1. __Oversampling of less freqency data points__ :- We will oversample the datapoints where the frequency is less than 8 for training.
# 2. __Train-test split__ :- We will now use stratified train test split with train-test split being (90-10) on the oversampled data

# %%
import numpy as np

np.random.seed(13)

train_df               = pd.read_csv('/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/Train.csv')
train_df['audio_path'] = '/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/'+train_df['ID']+'.mp3'

val_count    = train_df['transcription'].value_counts()
cols2sample  = val_count[val_count<=8].index.tolist()

for i in range(len(cols2sample)):
  
  target_transcript = cols2sample[i]

  count = val_count[target_transcript]

  aug_df   = train_df[train_df['transcription']==target_transcript].sample(9-count,replace=True)
  train_df = train_df.append(aug_df)


test_df                = pd.read_csv('/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/Test.csv')
test_df['audio_path']  = '/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/clips/'+test_df['ID']+'.mp3'

print(f'The shape of train data :- {train_df.shape} and shape of test data :- {test_df.shape}')
print(f'Columns in train data:- {train_df.columns.tolist()}')
print(f'Columns in test data:- {test_df.columns.tolist()}')

## We need to find the 'transcription column' from the test dataset.



train_df_sub = train_df[['audio_path','transcription']]

split = 0.1
train_data_audio,test_data_audio,train_data_target,test_data_target = train_test_split(train_df_sub['audio_path'],train_df_sub['transcription'],
                                                                                       random_state = 42,test_size=split,stratify=train_df_sub['transcription'])

train_data = pd.DataFrame(pd.concat({'audio_path':train_data_audio,'transcription':train_data_target},axis=1))
train_data = train_data.reset_index(drop=True)

test_data  = pd.DataFrame(pd.concat({'audio_path':test_data_audio,'transcription':test_data_target},axis=1))
test_data  = test_data.reset_index(drop=True)

print(f'The shape of train data and validation data after train-test split of {int((1-split)*100)}%-{int(split*100)}%  :- {train_data.shape,test_data.shape}')
# Out:
# The shape of train data :- (7520, 7) and shape of test data :- (1564, 6)
# Columns in train data:- ['ID', 'up_votes', 'down_votes', 'age', 'gender', 'transcription', 'audio_path']
# Columns in test data:- ['ID', 'up_votes', 'down_votes', 'age', 'gender', 'audio_path']
# The shape of train data and validation data after train-test split of 90%-10%  :- ((6768, 2), (752, 2))

# %%
train_data = Dataset.from_pandas(train_data)
test_data  = Dataset.from_pandas(test_data)

# %% [markdown]
# ## Creating and saving the Vocabulary
# We will save the character based vocabulary based on train transcriptions as vocab.json file in the model_asr folder.
# <br>
# Important points:-
# 1. We select some characters to remove and also convert entire batch of transcriptions to lowercase (to ensure uniformity) in both train and test dataset.
# 2. We also remove other column names like Downvotes, Gender, upvotes  because they were not needed as of now for analysis (even though they can be used for data augmentation while training but to reduce the runtime and get reasonable results early, we dropped those columns)
# 3. We eventually saved the characters in vocab.json in model_asr folder where it will be used by the model we will be calling in later stages

# %%
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\)\(\�]'
def remove_special_characters(batch):
  '''
      We remove special characters from each sentence.
  '''
  batch["transcription"] = re.sub(chars_to_ignore_regex, '', batch["transcription"]).lower() + " "
  return batch

train_data = train_data.map(remove_special_characters)
test_data  = test_data.map(remove_special_characters)

def extract_all_chars(batch):
  all_text = " ".join(batch["transcription"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

vocab_train = train_data.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=train_data.column_names)
vocab_test  = test_data.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=test_data.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6768.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=752.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
## vocabulary list from the train dataset
vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))  ## provides a list of characters from a list
vocab_dict = {v: k for k, v in enumerate(vocab_list)}

vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
print('The total vocabulary present in train transcriptions is ',len(vocab_dict))
# Out:
# The total vocabulary present in train transcriptions is  39

# %%
with open('/content/model_asr/vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# ## Tokenizing and Feature Extraction
# 1. We use the vocabulary extracted in the previous step and feed it into the Wav2Vec2CTCTokenizer and also specify some basic tokens to be used while training
# 2. The feature extraction steps will include the usage of feature_extractor with default values which enables us to get a float array of raw waveform of the clips. <br>
# One important thing to note over here is the fact that we are using the samling rate as 16000 hz/second because our model is trained on the input wav form of 16000 hz/second only
# 3. We eventually save our processor which includes our tokenizer (from point1 and feature extractor from point2) into the model_asr folder

# %%
tokenizer         = Wav2Vec2CTCTokenizer("/content/model_asr/vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

processor         = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

processor.save_pretrained("/content/model_asr")

# %% [markdown]
# ### Here we convert the speech file(audio clips) to array

# %%
def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["audio_path"])
    batch["speech"] = librosa.resample(np.asarray(speech_array[0].numpy()), 48_000, 16_000)
    batch["sampling_rate"] = 16_000
    batch["target_text"] = batch["transcription"]
    return batch

train_data = train_data.map(speech_file_to_array_fn, remove_columns=train_data.column_names)
test_data = test_data.map(speech_file_to_array_fn, remove_columns=test_data.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6768.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=752.0), HTML(value='')))

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values

    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

train_data = train_data.map(prepare_dataset, remove_columns=train_data.column_names, batch_size=8, batched=True)
test_data = test_data.map(prepare_dataset, remove_columns=test_data.column_names, batch_size=8, batched=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=846.0), HTML(value='')))
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# HBox(children=(FloatProgress(value=0.0, max=94.0), HTML(value='')))

# %% [markdown]
# ## We create a Data Collator class here.
# The entire code is taken here - https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81
# <br>
# The arguments corresponding to the class are explained in the docstring below. We tried not to experiment much with this class because a small tweak(like changing max_length) was giving really bizarre results and hence we took the class as it is without any changes from the repo specified above.
# <br>
# Also, we initialise the metric to be used for calculations which is Word Error Rate.

# %%
@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)
wer_metric = load_metric("wer")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1947.0, style=ProgressStyle(description…

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# ## Setting up model parameters
#
# 1. Model used is facebook's Wav2vec2-large-xlsr-53 which is a wav2vec model trained over 53 languages and we can finetune it to the language we need.
# 2. The parameters selected in below steps are obtained by running WandB sweeps. With default parameters we were not getting good results but the sweeps helped us a lot in getting a lift in performance.
# 3. The overall runtime of the trainer is about 12 hours on the GPU specified above and the checkpoints are saved in the folder model_asr as specified.

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53",
    attention_dropout=0.015715766711072065,
    feat_proj_dropout= 0.07570439532163029,
    activation_dropout=0.09145432252955588,
    hidden_dropout=0.0006515376406130203,
    # feat_proj_dropout=0.0,
    mask_time_prob=0.05353409500178331,
    layerdrop=0.018085056635857365,
    gradient_checkpointing=True,
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)


model.freeze_feature_extractor()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1451.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1261920069.0, style=ProgressStyle(descr…
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
  output_dir="/content/model_asr",
  
  group_by_length=True,
  per_device_train_batch_size=4,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=80,
  dataloader_num_workers= 32, 
  load_best_model_at_end=True,
  metric_for_best_model='wer',
  greater_is_better=False,
  fp16=True,
  seed=13,
  save_steps=100,
  eval_steps=500,
  logging_steps=500,
  learning_rate=0.000095637994662983496,
  lr_scheduler_type = 'cosine_with_restarts',
  warmup_steps=500,
  save_total_limit=1,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_data,
    eval_dataset=test_data,
    tokenizer=processor.feature_extractor,
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#     <div>
#
#       <progress value='67680' max='67680' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [67680/67680 11:52:53, Epoch 80/80]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>8.604700</td>
#       <td>2.917415</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.756800</td>
#       <td>0.628265</td>
#       <td>0.839800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.630200</td>
#       <td>0.284027</td>
#       <td>0.599917</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.388200</td>
#       <td>0.200102</td>
#       <td>0.516062</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.283800</td>
#       <td>0.141981</td>
#       <td>0.445140</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.223700</td>
#       <td>0.109221</td>
#       <td>0.415102</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.181800</td>
#       <td>0.083903</td>
#       <td>0.394243</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.146700</td>
#       <td>0.078651</td>
#       <td>0.394243</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.128900</td>
#       <td>0.081152</td>
#       <td>0.390071</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.128100</td>
#       <td>0.066647</td>
#       <td>0.378390</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.108100</td>
#       <td>0.066513</td>
#       <td>0.370046</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.108900</td>
#       <td>0.061731</td>
#       <td>0.376304</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.089300</td>
#       <td>0.058469</td>
#       <td>0.363788</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.089100</td>
#       <td>0.050504</td>
#       <td>0.357530</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.088900</td>
#       <td>0.058305</td>
#       <td>0.360033</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.075500</td>
#       <td>0.053049</td>
#       <td>0.357947</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.077900</td>
#       <td>0.042838</td>
#       <td>0.352524</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.069800</td>
#       <td>0.056708</td>
#       <td>0.352524</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.068800</td>
#       <td>0.045104</td>
#       <td>0.345432</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.063300</td>
#       <td>0.040462</td>
#       <td>0.344180</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.059400</td>
#       <td>0.051413</td>
#       <td>0.350855</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.063000</td>
#       <td>0.038115</td>
#       <td>0.341260</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.056500</td>
#       <td>0.042026</td>
#       <td>0.344180</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.050900</td>
#       <td>0.040628</td>
#       <td>0.342094</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.046800</td>
#       <td>0.034652</td>
#       <td>0.344597</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.053400</td>
#       <td>0.033135</td>
#       <td>0.340008</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.050200</td>
#       <td>0.041353</td>
#       <td>0.343763</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.045200</td>
#       <td>0.041090</td>
#       <td>0.344180</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.045700</td>
#       <td>0.038008</td>
#       <td>0.334168</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.046800</td>
#       <td>0.024592</td>
#       <td>0.330413</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.035800</td>
#       <td>0.023998</td>
#       <td>0.335836</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.042800</td>
#       <td>0.037426</td>
#       <td>0.337922</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.041800</td>
#       <td>0.034404</td>
#       <td>0.332916</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.039000</td>
#       <td>0.027352</td>
#       <td>0.334168</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.038000</td>
#       <td>0.032809</td>
#       <td>0.333751</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.031600</td>
#       <td>0.028004</td>
#       <td>0.339591</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.029700</td>
#       <td>0.031983</td>
#       <td>0.331247</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.036600</td>
#       <td>0.029188</td>
#       <td>0.339591</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.031000</td>
#       <td>0.028539</td>
#       <td>0.338757</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.031800</td>
#       <td>0.034416</td>
#       <td>0.336671</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.028700</td>
#       <td>0.030530</td>
#       <td>0.332499</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.027300</td>
#       <td>0.025516</td>
#       <td>0.327493</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.025200</td>
#       <td>0.026733</td>
#       <td>0.329579</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.027900</td>
#       <td>0.024629</td>
#       <td>0.328327</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.023900</td>
#       <td>0.022801</td>
#       <td>0.325824</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.025300</td>
#       <td>0.020196</td>
#       <td>0.328327</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.022800</td>
#       <td>0.024950</td>
#       <td>0.330830</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.026300</td>
#       <td>0.020288</td>
#       <td>0.330413</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.027100</td>
#       <td>0.022852</td>
#       <td>0.327493</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.029500</td>
#       <td>0.022139</td>
#       <td>0.329996</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.018300</td>
#       <td>0.019860</td>
#       <td>0.329996</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.023400</td>
#       <td>0.018428</td>
#       <td>0.326658</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.021400</td>
#       <td>0.023511</td>
#       <td>0.327910</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.023500</td>
#       <td>0.022485</td>
#       <td>0.328327</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.019800</td>
#       <td>0.020876</td>
#       <td>0.326658</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.018400</td>
#       <td>0.025500</td>
#       <td>0.327076</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.022100</td>
#       <td>0.025932</td>
#       <td>0.330830</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.020200</td>
#       <td>0.026172</td>
#       <td>0.325824</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.020800</td>
#       <td>0.016795</td>
#       <td>0.322069</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.018000</td>
#       <td>0.019153</td>
#       <td>0.324572</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.015700</td>
#       <td>0.017844</td>
#       <td>0.322069</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.022600</td>
#       <td>0.019231</td>
#       <td>0.322904</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.017800</td>
#       <td>0.022643</td>
#       <td>0.322069</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.017200</td>
#       <td>0.022382</td>
#       <td>0.324155</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.020500</td>
#       <td>0.018751</td>
#       <td>0.322486</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.014300</td>
#       <td>0.021971</td>
#       <td>0.322486</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.015100</td>
#       <td>0.019712</td>
#       <td>0.323321</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.011600</td>
#       <td>0.023845</td>
#       <td>0.322904</td>
#     </tr>
#     <
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# TrainOutput(global_step=67680, training_loss=0.1125287169321984, metrics={'train_runtime': 42779.5062, 'train_samples_per_second': 1.582, 'total_flos': 1.306027282581504e+17, 'epoch': 80.0, 'init_mem_cpu_alloc_delta': 1495904256, 'init_mem_gpu_alloc_delta': 1261915136, 'init_mem_cpu_peaked_delta': 0, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 607985664, 'train_mem_gpu_alloc_delta': 3782020608, 'train_mem_cpu_peaked_delta': 142192640, 'train_mem_gpu_peaked_delta': 1349468672})

# %% [markdown]
# ## Extracting the relevent checkpoint to be used on test dataset
# We extract the checkpoint having least eval-WER from the checkpoints saved in the folder. The model and tokenizer are initialised with the model and tokenizer saved in the checkpoint and usual steps to preprocess are applied again as we did for train data to get the results needed.

# %%
eval_steps = 500
eval_wer = []
for log_history in trainer.state.log_history:
  if 'eval_wer' in log_history.keys():
    eval_wer.append(log_history['eval_wer'])
steps_taken = [eval_steps*(i+1) for i in range(len(eval_wer))]

eval_dict = dict(zip(steps_taken,eval_wer))


import os
files = os.listdir('/content/model_asr')
checkpoints_available = []
for file in files:
  if 'checkpoint' in file:
    checkpoints_available.append(file)

least_loss = 2
for chkpts in checkpoints_available:  
  number = int(re.findall(r'\d+', chkpts)[0])
  if eval_dict[number]< least_loss:
    least_loss = eval_dict[number]
    chkpt2consider = '/content/model_asr/'+chkpts

# %%
chkpt2consider
# Out:
# '/content/model_asr/checkpoint-54000'

# %%
model = Wav2Vec2ForCTC.from_pretrained(chkpt2consider).to("cuda")
processor = Wav2Vec2Processor.from_pretrained("/content/model_asr")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
test_df = test_df[['audio_path']]
test_data  = Dataset.from_pandas(test_df)



def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["audio_path"])
    batch["speech"] = librosa.resample(np.asarray(speech_array[0].numpy()), 48_000, 16_000)
    batch["sampling_rate"] = 16_000
    # batch["speech"] = speech_array[0].numpy()
    # batch["sampling_rate"] = sampling_rate
    return batch

test_data = test_data.map(speech_file_to_array_fn, remove_columns=test_data.column_names)


# def resample(batch):
#     batch["speech"] = librosa.resample(np.asarray(batch["speech"]), 48_000, 16_000)
#     batch["sampling_rate"] = 16_000
#     return batch

# test_data = test_data.map(resample)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1564.0), HTML(value='')))

# %%
def evaluate(batch):
    inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

    with torch.no_grad():
        logits = model(inputs.input_values.to("cuda"), attention_mask=inputs.attention_mask.to("cuda")).logits
    
    pred_ids = torch.argmax(logits, dim=-1)
    batch["pred_strings"] = processor.batch_decode(pred_ids)
    return batch

# %%
result = test_data.map(evaluate, batched=True, batch_size=8)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=196.0), HTML(value='')))

# %% [markdown]
# ## Saving the transcriptions and post processing (part 1)
# In the first step of post processing, we remove special tokens from the transcriptions as well as any extra trailing space in the text attained.
# <br>
# Also, there was a datapoint which was empty (no transcription possible due to blank audio). In order to accommodate that, we make an adjustment based on sequence length of transcription attained (else the submissions were throwing error if '' is used instead of ' ').

# %%
outputdf = pd.read_csv('/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/Test.csv')
output = result["pred_strings"]
outputdf['transcription'] = output

# %%
subdf = outputdf[['ID','transcription']]
subdf.transcription=subdf.transcription.str.replace('\[PAD\]','')

subdf['transcription']=subdf['transcription'].str.strip()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
subdf['length'] = subdf['transcription'].str.len()
subdf['transcription'] = subdf.apply(lambda z: z['transcription'] if z['length']>0 else " ",axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Post Processing (part 2)
# 1. We define a function to match the transcriptions attained in previous step with the transcriptions available in train data. <br>
# Reason :- If we consider the problem statement, we can see that the geographical locations are finite (approx 700 unique transcriptions in train data corresponding to 700 locations in Senegal). Hence, any minute error in translation due to accent or gender can be rectified by finding the closest match with the available location in train data .
# <br>
# For example:- "Africatel avnes" attained from model can be mapped to "Africatel AVS" and on doing so, the WER is minimized even further.
# 2. We set up a threshold above which we will change the predictions if match happens and that was 45%. This means any transcription matching atleast 45% with the given set of transcriptions can be changed to the matched one.

# %%
def sim_text(text):
  match_dict = {}

  for vals in transcription_list_lower:
    # match_dict[vals] = fuzz.ratio(sorted(text),sorted(vals))
    match_dict[vals] = fuzz.ratio(text,vals)
  
  return max(match_dict,key=match_dict.get),max(match_dict.values())

# %%
train_df = pd.read_csv('/content/datasets/AI4D Baamtu Datamation - Automatic Speech Recognition in WOLOF/Train.csv')
outputdf = subdf.copy()

# %%
transcription_list = train_df['transcription'].unique().tolist()
transcription_list_lower = [a.lower() for a in transcription_list]
corresponding_dict = dict(zip(transcription_list_lower,transcription_list))

# %%
outputdf['results'] = outputdf['transcription'].apply(lambda z: sim_text(z))
outputdf['match_results'] = outputdf['results'].apply(lambda z: z[0])
outputdf['match_percent'] = outputdf['results'].apply(lambda z: z[1])

# %%
outputdf['match_results'] = outputdf['match_results'].map(corresponding_dict)
outputdf = outputdf.drop(['results'],axis=1)

# %%
outputdf['final'] = outputdf.apply(lambda z: z['match_results'] if z['match_percent']>=45 else z['transcription'],axis=1)
correcteddf = pd.DataFrame(columns=['ID','transcription'])
correcteddf['ID'] = outputdf['ID'].values
correcteddf['transcription'] = outputdf['final'].values
correcteddf.to_csv('last_model_trained_fuzzyratio.csv',index=False)

# %%
outputdf
# Out:
#                                                      ID  ...                                 final
# 0     00416cff4f818d3dfd99c9178ff0e268e7575500c8baa5...  ...                         Africatel AVS
# 1     00891ba561e80e135f9d12b9fa1347f0a2560998f7ea16...  ...  nan laay def ngir dem Tally bou Bess
# 2     00a508027ed4edf0bd3db79f45f4ed6e1b89fba6482c10...  ...                         Africatel AVS
# 3     00ac13cd0d93e35c1ff672cc106ad94d1ea9b93fcf049a...  ...                  Mosquée de Cambérène
# 4     00c2d5baf4719bf01b990a8924e99bda043cd462147193...  ...             Cité Safco Tivaoune Peulh
# ...                                                 ...  ...                                   ...
# 1559  ff0da457e7a3986035995912803e42261c5f5f448c126b...  ...                 Bank of africa Pikine
# 1560  ff1808218a15fa576c405314e4de4bda56c44f849ff1b5...  ...                         Tigo Almadies
# 1561  ff5b9a45d60600e875e0a031b1d7076c9cbdeb1c48c09c...  ...                   Gouy Gui Grand Mbao
# 1562  ff98e108ec61d3bd485734b83f21be77820549dab1cac1...  ...              Pharmacie Rokhaya Ouakam
# 1563  ffb6873f183e8995e50d1079f60f8e9d1018092e421578...  ...                               Orabank
#
# [1564 rows x 6 columns]
