# %%
import pandas as pd

# %%
dense161A = pd.read_csv('./submissions/submission_starter_notebook_densenet161_mixup_096_752_20ep--1115.csv')
dense161B = pd.read_csv('./submissions/submission_starter_notebook_densenet161_mixup_099_756_20ep--1232.csv')
dense201A = pd.read_csv('./submissions/submission_starter_notebook_densenet201_mixup_122_712_20ep--1456.csv')
res34 = pd.read_csv('./submissions/submission_starter_notebook_resnet34_mixup_119_894_20ep--1255.csv')

# %%
dense161A.head(10)
# Out:
#        ID  Ring-necked Dove  Black Cuckoo  Red-chested Cuckoo  \
# 0  019OYB          0.000011      0.000040            0.000170
# 1  01S9OX          0.000104      0.000115            0.000533
# 2  02CS12          0.027720      0.003303            0.002246
# 3  02LM3W          0.006652      0.000080            0.003198
# 4  0C3A2V          0.000713      0.002557            0.003818
# 5  0D4A65          0.000103      0.000232            0.001322
# 6  0DK4NW          0.032270      0.001856            0.001099
# 7  0E1YTK          0.000046      0.000193            0.000091
# 8  0E6W1B          0.000005      0.000190            0.000027
# 9  0EGKE8          0.000023      0.007598            0.001389
#
#    Fiery-necked Nightjar  Green Wood Hoopoe  Crested Barbet  Cape Batis  \
# 0               0.998933           0.000009        0.000012    0.000001
# 1               0.000102           0.000080        0.000247    0.000245
# ...

# %%
dense161B.head(10)
# Out:
#        ID  Ring-necked Dove  Black Cuckoo  Red-chested Cuckoo  \
# 0  019OYB          0.000161      0.000238            0.000375
# 1  01S9OX          0.000861      0.000563            0.001959
# 2  02CS12          0.025426      0.000528            0.007812
# 3  02LM3W          0.008627      0.001252            0.001095
# 4  0C3A2V          0.001068      0.003135            0.000671
# 5  0D4A65          0.000005      0.000039            0.000090
# 6  0DK4NW          0.041829      0.006958            0.001797
# 7  0E1YTK          0.000057      0.000023            0.000065
# 8  0E6W1B          0.000007      0.000002            0.000021
# 9  0EGKE8          0.000445      0.146336            0.007357
#
#    Fiery-necked Nightjar  Green Wood Hoopoe  Crested Barbet  Cape Batis  \
# 0               0.993335           0.000026        0.000315    0.000017
# 1               0.007304           0.000716        0.001685    0.004328
# ...

# %%
dense201A.head(10)
# Out:
#        ID  Ring-necked Dove  Black Cuckoo  Red-chested Cuckoo  \
# 0  019OYB          0.000033      0.000012            0.000738
# 1  01S9OX          0.000855      0.000315            0.000950
# 2  02CS12          0.019698      0.001680            0.001783
# 3  02LM3W          0.005436      0.000055            0.000611
# 4  0C3A2V          0.002915      0.050810            0.002112
# 5  0D4A65          0.000206      0.000545            0.000226
# 6  0DK4NW          0.051328      0.007015            0.004328
# 7  0E1YTK          0.000025      0.000049            0.000020
# 8  0E6W1B          0.000010      0.000025            0.000200
# 9  0EGKE8          0.000224      0.234119            0.002359
#
#    Fiery-necked Nightjar  Green Wood Hoopoe  Crested Barbet  Cape Batis  \
# 0               0.995841           0.000023        0.000976    0.000178
# 1               0.000527           0.000406        0.000661    0.001988
# ...

# %%
res34.head(10)
# Out:
#        ID  Ring-necked Dove  Black Cuckoo  Red-chested Cuckoo  \
# 0  019OYB          0.000172      0.000087            0.003406
# 1  01S9OX          0.000680      0.000363            0.001499
# 2  02CS12          0.006613      0.002611            0.000155
# 3  02LM3W          0.042327      0.001396            0.006005
# 4  0C3A2V          0.000613      0.004822            0.002141
# 5  0D4A65          0.005326      0.000624            0.013350
# 6  0DK4NW          0.101063      0.010863            0.005643
# 7  0E1YTK          0.000355      0.001437            0.000497
# 8  0E6W1B          0.000008      0.000025            0.000006
# 9  0EGKE8          0.000208      0.163366            0.000567
#
#    Fiery-necked Nightjar  Green Wood Hoopoe  Crested Barbet  Cape Batis  \
# 0               0.982028           0.000041        0.001670    0.000189
# 1               0.000332           0.000312        0.000417    0.001163
# ...

# %%
sub = pd.concat([dense161A['ID'], 
                (  .35 * dense161A.iloc[:, 1:] 
                 + .2 * dense161B.iloc[:, 1:] 
                 + .2 * dense201A.iloc[:, 1:] 
                 + .25 * res34.iloc[:, 1:]).iloc[:,:]], 
                axis=1)
sub.head(10)
# Out:
#        ID  Ring-necked Dove  Black Cuckoo  Red-chested Cuckoo  \
# 0  019OYB          0.000086      0.000086            0.001134
# 1  01S9OX          0.000550      0.000307            0.001143
# 2  02CS12          0.020380      0.002250            0.002744
# 3  02LM3W          0.015723      0.000638            0.002962
# 4  0C3A2V          0.001199      0.012889            0.002428
# 5  0D4A65          0.001410      0.000354            0.003863
# 6  0DK4NW          0.055192      0.006160            0.003020
# 7  0E1YTK          0.000121      0.000441            0.000173
# 8  0E6W1B          0.000007      0.000078            0.000055
# 9  0EGKE8          0.000194      0.119592            0.002571
#
#    Fiery-necked Nightjar  Green Wood Hoopoe  Crested Barbet  Cape Batis  \
# 0               0.992969           0.000023        0.000680    0.000087
# 1               0.001685           0.000330        0.000660    0.001640
# ...

# %%
sub.to_csv(f"./submissions/blend_001_35202025.csv", index=False)

# %%
sub.shape
# Out:
# (911, 41)
